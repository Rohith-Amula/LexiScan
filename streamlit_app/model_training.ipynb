# %%
# Install dependencies
# %pip install tensorflow keras matplotlib

# Import libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize images
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build ANN Model
model = Sequential([
    Flatten(input_shape=(28, 28)),         # Input: 28x28 grayscale image
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')        # Output: 10 digits (0–9)
])

# Compile model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train model
history = model.fit(
    x_train, y_train,
    epochs=20,
    batch_size=128,
    validation_data=(x_test, y_test),
    callbacks=[early_stop]
)

# Save model
model.save("saved_model/model.h5")

# Evaluate model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f}")

# Plot accuracy and loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label="Training Accuracy")
plt.plot(history.history['val_accuracy'], label="Validation Accuracy")
plt.legend()
plt.title("Accuracy Curve")

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label="Training Loss")
plt.plot(history.history['val_loss'], label="Validation Loss")
plt.legend()
plt.title("Loss Curve")

plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: tensorflow in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (2.19.0)
# Requirement already satisfied: keras in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (3.9.2)
# Requirement already satisfied: matplotlib in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: packaging in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: setuptools in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: namex in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from keras) (0.0.9)
# Requirement already satisfied: optree in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from keras) (0.15.0)
# Requirement already satisfied: rich in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from keras) (14.0.0)
# Requirement already satisfied: pillow>=8 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\onedrive\documents\ocr\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\ASUS\OneDrive\Documents\OCR\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# c:\Users\ASUS\OneDrive\Documents\OCR\venv\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7692 - loss: 0.7296 - val_accuracy: 0.9570 - val_loss: 0.1403
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9466 - loss: 0.1748 - val_accuracy: 0.9677 - val_loss: 0.1002
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9599 - loss: 0.1291 - val_accuracy: 0.9735 - val_loss: 0.0858
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9678 - loss: 0.1048 - val_accuracy: 0.9750 - val_loss: 0.0811
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9730 - loss: 0.0876 - val_accuracy: 0.9763 - val_loss: 0.0758
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9748 - loss: 0.0804 - val_accuracy: 0.9758 - val_loss: 0.0828
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9780 - loss: 0.0672 - val_accuracy: 0.9781 - val_loss: 0.0722
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9794 - loss: 0.0635 - val_accuracy: 0.9793 - val_loss: 0.0742
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9818 - loss: 0.0581 - val_accuracy: 0.9789 - val_loss: 0.0749
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9833 - loss: 0.0529 - val_accuracy: 0.9811 - val_loss: 0.0670
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9837 - loss: 0.0518 - val_accuracy: 0.9806 - val_loss: 0.0700
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9845 - loss: 0.0464 - val_accuracy: 0.9827 - val_loss: 0.0666
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9839 - loss: 0.0472 - val_accuracy: 0.9817 - val_loss: 0.0695
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9857 - loss: 0.0452 - val_accuracy: 0.9818 - val_loss: 0.0674
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9858 - loss: 0.0439 - val_accuracy: 0.9821 - val_loss: 0.0669
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 0.9827
